# %%
import pandas as ps

# %%
tesla_df = ps.read_csv('TSLA.csv')
tesla_df.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 2572   72279300
# 2573   76779200
# 2574   86406800
# 2575  109476800
# 2576   73640900

# %%
tesla_df = tesla_df.loc[tesla_df['Close'] // 6 != 0]
tesla_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000    6.160000    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000    6.198000    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000    6.680000    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000    6.914000    6.914000
# 104   2010-11-24    7.054000    7.194000    6.866000    7.094000    7.094000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 97     13114500
# ...

# %%
tesla_df['Close'].describe()
# Out:
# count    2150.000000
# mean       57.526488
# std        58.591458
# min         6.002000
# 25%        38.124500
# 50%        47.106001
# 75%        62.237001
# max       498.320007
# Name: Close, dtype: float64

# %%
filter = tesla_df.notna()

# %%
tesla_df = tesla_df[filter]
tesla_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000    6.160000    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000    6.198000    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000    6.680000    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000    6.914000    6.914000
# 104   2010-11-24    7.054000    7.194000    6.866000    7.094000    7.094000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 97     13114500
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tesla_df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 97    2010-11-15    6.044000    6.588000    6.044000    6.160000    6.160000
# 101   2010-11-19    6.032000    6.274000    5.940000    6.198000    6.198000
# 102   2010-11-22    6.314000    6.690000    6.300000    6.680000    6.680000
# 103   2010-11-23    6.658000    7.136000    6.438000    6.914000    6.914000
# 104   2010-11-24    7.054000    7.194000    6.866000    7.094000    7.094000
# ...          ...         ...         ...         ...         ...         ...
# 2572  2020-09-16  439.869995  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  415.600006  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  447.940002  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  453.130005  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  429.600006  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 97     13114500
# ...

# %%
g = sns.pairplot(
    tesla_df,
    x_vars = ['Date'],
    y_vars = ['Close', ],
    hue='Date'
)
g.fig.set_size_inches(15, 15)

# %%
open_max = tesla_df['Open'].max()
open_min = tesla_df['Open'].min()


def normal_date(one_serias):
    return (one_serias - open_min) / (open_max - open_min)

tesla_df['Open'] = tesla_df['Open'].apply(normal_date)
tesla_df
# Out:
#             Date      Open        High         Low       Close   Adj Close  \
# 97    2010-11-15  0.000584    6.588000    6.044000    6.160000    6.160000
# 101   2010-11-19  0.000560    6.274000    5.940000    6.198000    6.198000
# 102   2010-11-22  0.001128    6.690000    6.300000    6.680000    6.680000
# 103   2010-11-23  0.001821    7.136000    6.438000    6.914000    6.914000
# 104   2010-11-24  0.002619    7.194000    6.866000    7.094000    7.094000
# ...          ...       ...         ...         ...         ...         ...
# 2572  2020-09-16  0.874553  457.790009  435.309998  441.760010  441.760010
# 2573  2020-09-17  0.825660  437.790009  408.000000  423.429993  423.429993
# 2574  2020-09-18  0.890811  451.000000  428.799988  442.149994  442.149994
# 2575  2020-09-21  0.901266  455.679993  407.070007  449.390015  449.390015
# 2576  2020-09-22  0.853864  437.760010  417.600006  424.230011  424.230011
#
#          Volume
# 97     13114500
# 101     5752500
# ...

# %%
tesla_df.head()


for i in tesla_df:
    print(i)
    
print(tesla_df['Open'].index)
# Out:
# Date
# Open
# High
# Low
# Close
# Adj Close
# Volume
# Int64Index([  97,  101,  102,  103,  104,  105,  106,  107,  108,  109,
#             ...
#             2567, 2568, 2569, 2570, 2571, 2572, 2573, 2574, 2575, 2576],
#            dtype='int64', length=2150)

# %%
new_df = ps.DataFrame(columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'])

for i in range(0, 10):
    new_vector = []
    for j in range (0, 7):
        new_vector.append((i+j) ** j)
        
    new_df.loc[len(new_df.index)] = new_vector

# %%
tesla_df = ps.concat([tesla_df, new_df], ignore_index=True)
tesla_df.tail(10)
# Out:
#      Date  Open   High     Low    Close  Adj Close    Volume
# 2160    1   1.0    4.0    27.0    256.0     3125.0     46656
# 2161    1   2.0    9.0    64.0    625.0     7776.0    117649
# 2162    1   3.0   16.0   125.0   1296.0    16807.0    262144
# 2163    1   4.0   25.0   216.0   2401.0    32768.0    531441
# 2164    1   5.0   36.0   343.0   4096.0    59049.0   1000000
# 2165    1   6.0   49.0   512.0   6561.0   100000.0   1771561
# 2166    1   7.0   64.0   729.0  10000.0   161051.0   2985984
# 2167    1   8.0   81.0  1000.0  14641.0   248832.0   4826809
# 2168    1   9.0  100.0  1331.0  20736.0   371293.0   7529536
# 2169    1  10.0  121.0  1728.0  28561.0   537824.0  11390625

# %%
tesla_df
# Out:
#             Date       Open     High       Low      Close   Adj Close  \
# 0     2010-11-15   0.000584    6.588     6.044      6.160       6.160
# 1     2010-11-19   0.000560    6.274     5.940      6.198       6.198
# 2     2010-11-22   0.001128    6.690     6.300      6.680       6.680
# 3     2010-11-23   0.001821    7.136     6.438      6.914       6.914
# 4     2010-11-24   0.002619    7.194     6.866      7.094       7.094
# ...          ...        ...      ...       ...        ...         ...
# 2165           1   6.000000   49.000   512.000   6561.000  100000.000
# 2166           1   7.000000   64.000   729.000  10000.000  161051.000
# 2167           1   8.000000   81.000  1000.000  14641.000  248832.000
# 2168           1   9.000000  100.000  1331.000  20736.000  371293.000
# 2169           1  10.000000  121.000  1728.000  28561.000  537824.000
#
#         Volume
# 0     13114500
# 1      5752500
# 2      7648500
# 3      7889000
# 4      7125000
# ...        ...
# ...
